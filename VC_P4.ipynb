# %% [markdown]
# #Paquetes necesarios

# %%
import cv2  
import math 

from ultralytics import YOLO
# Out:
# WARNING  Python>=3.10 is required, but Python==3.9.20 is currently installed

# %% [markdown]
# Entrenamiento del modelo para detectar matrículas

# %%
model = YOLO("yolo11n.pt")

results = model.train(data="datasets/matriculas/data.yaml", epochs=20, imgsz=640)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 model = YOLO("yolo11n.pt")
#       3 results = model.train(data="datasets/matriculas/data.yaml", epochs=20, imgsz=640)
#
# NameError: name 'YOLO' is not defined

# %% [markdown]
# Uso del modelo para la detección.

# %%
model = YOLO("runs/detect/train3/weights/best.pt")
filename = "C0142.MP4"

#results = model.track(source=filename, show=True)  # BoT-SORT tracker (por defecto)
results = model.track(source=filename, show=True, tracker="bytetrack.yaml")  # ByteTrack tracker

cv2.destroyAllWindows()
# Out:
# WARNING  inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/2832) c:\Users\Acer\Desktop\Universidad\VC\Prcticas\P4\P4\C0142.MP4: 384x640 1 License-Plate, 21.9ms
# video 1/1 (frame 2/2832) c:\Users\Acer\Desktop\Universidad\VC\Prcticas\P4\P4\C0142.MP4: 384x640 1 License-Plate, 18.5ms
# video 1/1 (frame 3/2832) c:\Users\Acer\Desktop\Universidad\VC\Prcticas\P4\P4\C0142.MP4: 384x640 (no detections), 24.0ms
# video 1/1 (frame 4/2832) c:\Users\Acer\Desktop\Universidad\VC\Prcticas\P4\P4\C0142.MP4: 384x640 (no detections), 20.2ms
# video 1/1 (frame 5/2832) c:\Users\Acer\Desktop\Universidad\VC\Prcticas\P4\P4\C0142.MP4: 384x640 (no detections), 15.9ms
# video 1/1 (frame 6/2832) c:\Users\Acer\Desktop\Universidad\VC\Prcticas\P4\P4\C0142.MP4: 384x640 (no detections), 19.4ms
# video 1/1 (frame 7/2832) c:\Users\Acer\Desktop\Universidad\VC\Prcticas\P4\P4\C0142.MP4: 384x640 (no detections), 21.0ms
# video 1/1 (frame 8/2832) c:\Users\Acer\Desktop\Universidad\VC\Prcticas\P4\P4\C0142.MP4: 384x640 (no detections), 19.4ms
# video 1/1 (frame 9/2832) c:\Users\Acer\Desktop\Universidad\VC\Prcticas\P4\P4\C0142.MP4: 384x640 (no detections), 11.2ms
# video 1/1 (frame 10/2832) c:\Users\Acer\Desktop\Universidad\VC\Prcticas\P4\P4\C0142.MP4: 384x640 (no detections), 6.3ms
# video 1/1 (frame 11/2832) c:\Users\Acer\Desktop\Universidad\VC\Prcticas\P4\P4\C0142.MP4: 384x640 (no detections), 9.0ms
# video 1/1 (frame 12/2832) c:\Users\Acer\Desktop\Universidad\VC\Prcticas\P4\P4\C0142.MP4: 384x640 (no detections), 10.3ms
# video 1/1 (frame 13/2832) c:\Users\Acer\Desktop\Universidad\VC\Prcticas\P4\P4\C0142.MP4: 384x640 (no detections), 13.1ms
# video 1/1 (frame 14/2832) c:\Users\Acer\Desktop\Universidad\VC\Prcticas\P4\P4\C0142.MP4: 384x640 (no detections), 14.3ms
# video 1/1 (frame 15/2832) c:\Users\Acer\Desktop\Universidad\VC\Prcticas\P4\P4\C0142.MP4: 384x640 (no detections), 9.9ms
# video 1/1 (frame 16/2832) c:\Users\Acer\Desktop\Universidad\VC\Prcticas\P4\P4\C0142.MP4: 384x640 (no detections), 14.0ms
# video 1/1 (frame 17/2832) c:\Users\Acer\Desktop\Universidad\VC\Prcticas\P4\P4\C0142.MP4: 384x640 (no detections), 14.1ms
# video 1/1 (frame 18/2832) c:\Users\Acer\Desktop\Universidad\VC\Prcticas\P4\P4\C0142.MP4: 384x640 (no detections), 12.0ms
# video 1/1 (frame 19/2832) c:\Users\Acer\Desktop\Universidad\VC\Prcticas\P4\P4\C0142.MP4: 384x640 (no detections), 13.6ms
# video 1/1 (frame 20/2832) c:\Users\Acer\Desktop\Universidad\VC\Prcticas\P4\P4\C0142.MP4: 384x640 (no detections), 12.6ms
# video 1/1 (frame 21/2832) c:\Users\Acer\Desktop\Universidad\VC\Prcticas\P4\P4\C0142.MP4: 384x640 (no detections), 16.0ms
# video 1/1 (frame 22/2832) c:\Users\Acer\Desktop\Universidad\VC\Prcticas\P4\P4\C0142.MP4: 384x640 (no detections), 26.4ms
# video 1/1 (frame 23/2832) c:\Users\Acer\Desktop\Universidad\VC\Prcticas\P4\P4\C0142.MP4: 384x640 (no detections), 20.1ms
# video 1/1 (frame 24/2832) c:\Users\Acer\Desktop\Universidad\VC\Prcticas\P4\P4\C0142.MP4: 384x640 (no detections), 13.2ms
# video 1/1 (frame 25/2832) c:\Users\Acer\Desktop\Universidad\VC\Prcticas\P4\P4\C0142.MP4: 384x640 (no detections), 12.5ms
# video 1/1 (frame 26/2832) c:\Users\Acer\Desktop\Universidad\VC\Prcticas\P4\P4\C0142.MP4: 384x640 (no detections), 6.6ms
# video 1/1 (frame 27/2832) c:\Users\Acer\Desktop\Universidad\VC\Prcticas\P4\P4\C0142.MP4: 384x640 (no detections), 13.3ms
# video 1/1 (frame 28/2832) c:\Users\Acer\Desktop\Universidad\VC\Prcticas\P4\P4\C0142.MP4: 384x640 (no detections), 10.4ms
# video 1/1 (frame 29/2832) c:\Users\Acer\Desktop\Universidad\VC\Prcticas\P4\P4\C0142.MP4: 384x640 (no detections), 14.8ms
# video 1/1 (frame 30/2832) c:\Users\Acer\Desktop\Universidad\VC\Prcticas\P4\P4\C0142.MP4: 384x640 (no detections), 15.7ms
# video 1/1 (frame 31/2832) c:\Users\Acer\Desktop\Universidad\VC\Prcticas\P4\P4\C0142.MP4: 384x640 (no detections), 12.6ms
# video 1/1 (frame 32/2832) c:\Users\Acer\Desktop\Universidad\VC\Prcticas\P4\P4\C0142.MP4: 384x640 (no detections), 13.4ms
# video 1/1 (frame 33/2832) c:\Users\Acer\Desktop\Universidad\VC\Prcticas\P4\P4\C0142.MP4: 384x640 (no detections), 15.5ms
# video 1/1 (frame 34/2832) c:\Users\Acer\Desktop\Universidad\VC\Prcticas\P4\P4\C0142.MP4: 384x640 (no detections), 13.5ms
# video 1/1 (frame 35/2832) c:\Users\Acer\Desktop\Universidad\VC\Prcticas\P4\P4\C0142.MP4: 384x640 (no detections), 15.4ms
# video 1/1 (frame 36/2832) c:\Users\Acer\Desktop\Universidad\VC\Prcticas\P4\P4\C0142.MP4: 384x640 (no detections), 14.7ms
# video 1/1 (frame 37/2832) c:\Users\Acer\Desktop\Universidad\VC\Prcticas\P4\P4\C0142.MP4: 384x640 (no detections), 13.1ms
# video 1/1 (frame 38/2832) c:\Users\Acer\Desktop\Universidad\VC\Prcticas\P4\P4\C0142.MP4: 384x640 (no detections), 13.8ms
# video 1/1 (frame 39/2832) c:\Users\Acer\Desktop\Universidad\VC\Prcticas\P4\P4\C0142.MP4: 384x640 (no detections), 13.0ms
# video 1/1 (frame 40/2832) c:\Users\Acer\Desktop\Universidad\VC\Prcticas\P4\P4\C0142.MP4: 384x640 (no detections), 13.2ms
# video 1/1 (frame 41/2832) c:\Users\Acer\Desktop\Universidad\VC\Prcticas\P4\P4\C0142.MP4: 384x640 (no detections), 12.7ms
# video 1/1 (frame 42/2832) c:\Users\Acer\Desktop\Universidad\VC\Prcticas\P4\P4\C0142.MP4: 384x640 (no detections), 10.6ms
# video 1/1 (frame 43/2832) c:\Users\Acer\Desktop\Universidad\VC\Prcticas\P4\P4\C0142.MP4: 384x640 (no detections), 11.9ms
# video 1/1 (frame 44/2832) c:\Users\Acer\Desktop\Universidad\VC\Prcticas\P4\P4\C0142.MP4: 384x640 (no detections), 12.5ms
# video 1/1 (frame 45/2832) c:\Users\Acer\Desktop\Universidad\VC\Prcticas\P4\P4\C0142.MP4: 384x640 (no detections), 12.8ms
# video 1/1 (frame 46/2832) c:\Users\Acer\Desktop\Universidad\VC\Prcticas\P4\P4\C0142.MP4: 384x640 (no detections), 12.9ms
# video 1/1 (frame 47/2832) c:\Users\Acer\Desktop\Universidad\VC\Prcticas\P4\P4\C0142.MP4: 384x640 (no detections), 13.0ms
# video 1/1 (frame 48/2832) c:\Users\Acer\Desktop\Universidad\VC\Prcticas\P4\P4\C0142.MP4: 384x640 (no detections), 12.0ms
# video 1/1 (frame 49/2832) c:\Users\Acer\Desktop\Universidad\VC\Prcticas\P4\P4\C0142.MP4: 384x640 (no detections), 17.0ms
# video 1/1 (frame 50/2832) c:\Users\Acer\Desktop\Universidad\VC\Prcticas\P4\P4\C0142.MP4: 384x640 (no detections), 11.3ms
# video 1/1 (frame 51/2832) c:\Users\Acer\Desktop\Universidad\VC\Prcticas\P4\P4\C0142.MP4: 384x640 (no detections), 10.7ms
# video 1/1 (frame 52/2832) c:\Users\Acer\Desktop\Universidad\VC\Prcticas\P4\P4\C0142.MP4: 384x640 (no detections), 13.2ms
# video 1/1 (frame 53/2832) c:\Users\Acer\Desktop\Universidad\VC\Prcticas\P4\P4\C0142.MP4: 384x640 (no detections), 14.0ms
# video 1/1 (frame 54/2832) c:\Users\Acer\Desktop\Universidad\VC\Prcticas\P4\P4\C0142.MP4: 384x640 (no detections), 12.5ms
# video 1/1 (frame 55/2832) c:\Users\Acer\Desktop\Universidad\VC\Prcticas\P4\P4\C0142.MP4: 384x640 (no detections), 13.5ms
# video 1/1 (frame 56/2832) c:\Users\Acer\Desktop\Universidad\VC\Prcticas\P4\P4\C0142.MP4: 384x640 (no detections), 12.5ms
# video 1/1 (frame 57/2832) c:\Users\Acer\Desktop\Universidad\VC\Prcticas\P4\P4\C0142.MP4: 384x640 (no detections), 13.3ms
# video 1/1 (frame 58/2832) c:\Users\Acer\Desktop\Universidad\VC\Prcticas\P4\P4\C0142.MP4: 384x640 (no detections), 32.4ms
# video 1/1 (frame 59/2832) c:\Users\Acer\Desktop\Universidad\VC\Prcticas\P4\P4\C0142.MP4: 384x640 (no detections), 22.0ms
# video 1/1 (frame 60/2832) c:\Users\Acer\Desktop\Universidad\VC\Prcticas\P4\P4\C0142.MP4: 384x640 (no detections), 6.8ms
# video 1/1 (frame 61/2832) c:\Users\Acer\Desktop\Universidad\VC\Prcticas\P4\P4\C0142.MP4: 384x640 (no detections), 10.2ms
# video 1/1 (frame 62/2832) c:\Users\Acer\Desktop\Universidad\VC\Prcticas\P4\P4\C0142.MP4: 384x640 (no detections), 5.2ms
# video 1/1 (frame 63/2832) c:\Users\Acer\Desktop\Universidad\VC\Prcticas\P4\P4\C0142.MP4: 384x640 (no detections), 7.0ms
# video 1/1 (frame 64/2832) c:\Users\Acer\Desktop\Universidad\VC\Prcticas\P4\P4\C0142.MP4: 384x640 (no detections), 9.8ms
# video 1/1 (frame 65/2832) c:\Users\Acer\Desktop\Universidad\VC\Prcticas\P4\P4\C0142.MP4: 384x640 (no detections), 13.0ms
# video 1/1 (frame 66/2832) c:\Users\Acer\Desktop\Universidad\VC\Prcticas\P4\P4\C0142.MP4: 384x640 (no detections), 11.4ms
# video 1/1 (frame 67/2832) c:\Users\Acer\Desktop\Universidad\VC\Prcticas\P4\P4\C0142.MP4: 384x640 (no detections), 6.7ms
# video 1/1 (frame 68/2832) c:\Users\Acer\Desktop\Universidad\VC\Prcticas\P4\P4\C0142.MP4: 384x640 (no detections), 13.4ms
# video 1/1 (frame 69/2832) c:\Users\Acer\Desktop\Universidad\VC\Prcticas\P4\P4\C0142.MP4: 384x640 (no detections), 15.1ms
# video 1/1 (frame 70/2832) c:\Users\Acer\Desktop\Universidad\VC\Prcticas\P4\P4\C0142.MP4: 384x640 (no detections), 6.7ms
# video 1/1 (frame 71/2832) c:\Users\Acer\Desktop\Universidad\VC\Prcticas\P4\P4\C0142.MP4: 384x640 (no detections), 9.8ms
# video 1/1 (frame 72/2832) c:\Users\Acer\Desktop\Universidad\VC\Prcticas\P4\P4\C0142.MP4: 384x640 (no detections), 12.0ms
# video 1/1 (frame 73/2832) c:\Users\Acer\Desktop\Universidad\VC\Prcticas\P4\P4\C0142.MP4: 384x640 (no detections), 13.0ms
# video 1/1 (frame 74/2832) c:\Users\Acer\Desktop\Universidad\VC\Prcticas\P4\P4\C0142.MP4: 384x640 (no detections), 12.6ms
# video 1/1 (frame 75/2832) c:\Users\Acer\Desktop\Universidad\VC\Prcticas\P4\P4\C0142.MP4: 384x640 (no detections), 13.5ms
# video 1/1 (frame 76/2832) c:\Users\Acer\Desktop\Universidad\VC\Prcticas\P4\P4\C0142.MP4: 384x640 (no detections), 6.7ms
# video 1/1 (frame 77/2832) c:\Users\Acer\Desktop\Universidad\VC\Prcticas\P4\P4\C0142.MP4: 384x640 (no detections), 10.3ms
# video 1/1 (frame 78/2832) c:\Users\Acer\Desktop\Universidad\VC\Prcticas\P4\P4\C0142.MP4: 384x640 (no detections), 12.5ms
# video 1/1 (frame 79/2832) c:\Users\Acer\Desktop\Universidad\VC\Prcticas\P4\P4\C0142.MP4: 384x640 (no detections), 10.7ms
# video 1/1 (frame 80/2832) c:\Users\Acer\Desktop\Universidad\VC\Prcticas\P4\P4\C0142.MP4: 384x640 (no detections), 8.4ms
# video 1/1 (frame 81/2832) c:\Users\Acer\Desktop\Universidad\VC\Prcticas\P4\P4\C0142.MP4: 384x640 (no detections), 12.1ms
# video 1/1 (frame 82/2832) c:\Users\Acer\Desktop\Universidad\VC\Prcticas\P4\P4\C0142.MP4: 384x640 (no detections), 7.1ms
# video 1/1 (frame 83/2832) c:\Users\Acer\Desktop\Universidad\VC\Prcticas\P4\P4\C0142.MP4: 384x640 (no detections), 10.1ms
# video 1/1 (frame 84/2832) c:\Users\Acer\Desktop\Universidad\VC\Prcticas\P4\P4\C0142.MP4: 384x640 (no detections), 5.1ms
# video 1/1 (frame 85/2832) c:\Users\Acer\Desktop\Universidad\VC\Prcticas\P4\P4\C0142.MP4: 384x640 (no detections), 7.0ms
# video 1/1 (frame 86/2832) c:\Users\Acer\Desktop\Universidad\VC\Prcticas\P4\P4\C0142.MP4: 384x640 (no detections), 11.3ms
# video 1/1 (frame 87/2832) c:\Users\Acer\Desktop\Universidad\VC\Prcticas\P4\P4\C0142.MP4: 384x640 (no detections), 13.3ms
# video 1/1 (frame 88/2832) c:\Users\Acer\Desktop\Universidad\VC\Prcticas\P4\P4\C0142.MP4: 384x640 (no detections), 11.1ms
# video 1/1 (frame 89/2832) c:\Users\Acer\Desktop\Universidad\VC\Prcticas\P4\P4\C0142.MP4: 384x640 (no detections), 12.6ms
# video 1/1 (frame 90/2832) c:\Users\Acer\Desktop\Universidad\VC\Prcticas\P4\P4\C0142.MP4: 384x640 (no detections), 7.3ms
# video 1/1 (frame 91/2832) c:\Users\Acer\Desktop\Universidad\VC\Prcticas\P4\P4\C0142.MP4: 384x640 (no detections), 11.1ms
# video 1/1 (frame 92/2832) c:\Users\Acer\Desktop\Universidad\VC\Prcticas\P4\P4\C0142.MP4: 384x640 (no detections), 11.3ms
# video 1/1 (frame 93/2832) c:\Users\Acer\Desktop\Universidad\VC\Prcticas\P4\P4\C0142.MP4: 384x640 (no detections), 9.2ms
# video 1/1 (frame 94/2832) c:\Users\Acer\Desktop\Universidad\VC\Prcticas\P4\P4\C0142.MP4: 384x640 (no detections), 11.7ms
# video 1/1 (frame 95/2832) c:\Users\Acer\Desktop\Universidad\VC\Prcticas\P4\P4\C0142.MP4: 384x640 (no detections), 12.6ms
# video 1/1 (frame 96/2832) c:\Users\Acer\Desktop\Universidad\VC\Prcticas\P4\P4\C0142.MP4: 384x640 (no detections),
2832) c:\Users\Acer\Desktop\Universidad\VC\Prcticas\P4\P4\C0142.MP4: 384x640 (no detections), 15.5ms
# video 1/1 (frame 1280/2832) c:\Users\Acer\Desktop\Universidad\VC\Prcticas\P4\P4\C0142.MP4: 384x640 2 License-Plates, 14.7ms
# video 1/1 (frame 1281/2832) c:\Users\Acer\Desktop\Universidad\VC\Prcticas\P4\P4\C0142.MP4: 384x640 (no detections), 14.8ms
# video 1/1 (frame 1282/2832) c:\Users\Acer\Desktop\Universidad\VC\Prcticas\P4\P4\C0142.MP4: 384x640 (no detections), 17.6ms
# video 1/1 (frame 1283/2832) c:\Users\Acer\Desktop\Universidad\VC\Prcticas\P4\P4\C0142.MP4: 384x640 (no detections), 13.4ms
# video 1/1 (frame 1284/2832) c:\Users\Acer\Desktop\Universidad\VC\Prcticas\P4\P4\C0142.MP4: 384x640 (no detections), 27.7ms
# video 1/1 (frame 1285/2832) c:\Users\Acer\Desktop\Universidad\VC\Prcticas\P4\P4\C0142.MP4: 384x640 (no detections), 12.4ms
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 5
#       2 filename = "C0142.MP4"
#       4 #results = model.track(source=filename, show=True)  # BoT-SORT tracker (por defecto)
# ----> 5 results = model.track(source=filename, show=True, tracker="bytetrack.yaml")  # ByteTrack tracker
#       7 cv2.destroyAllWindows()
#
# File c:\Users\Acer\anaconda3\envs\VC_P4\lib\site-packages\ultralytics\engine\model.py:601, in Model.track(self, source, stream, persist, **kwargs)
#     599 kwargs["batch"] = kwargs.get("batch") or 1  # batch-size 1 for tracking in videos
#     600 kwargs["mode"] = "track"
# --> 601 return self.predict(source=source, stream=stream, **kwargs)
#
# File c:\Users\Acer\anaconda3\envs\VC_P4\lib\site-packages\ultralytics\engine\model.py:554, in Model.predict(self, source, stream, predictor, **kwargs)
#     552 if prompts and hasattr(self.predictor, "set_prompts"):  # for SAM-type models
#     553     self.predictor.set_prompts(prompts)
# --> 554 return self.predictor.predict_cli(source=source) if is_cli else self.predictor(source=source, stream=stream)
#
# File c:\Users\Acer\anaconda3\envs\VC_P4\lib\site-packages\ultralytics\engine\predictor.py:168, in BasePredictor.__call__(self, source, model, stream, *args, **kwargs)
#     166     return self.stream_inference(source, model, *args, **kwargs)
#     167 else:
# --> 168     return list(self.stream_inference(source, model, *args, **kwargs))
#
# File c:\Users\Acer\anaconda3\envs\VC_P4\lib\site-packages\torch\utils\_contextlib.py:57, in _wrap_generator.<locals>.generator_context(*args, **kwargs)
#      54         else:
#      55             # Pass the last request to the generator and get its response
#      56             with ctx_factory():
# ---> 57                 response = gen.send(request)
#      59 # We let the exceptions raised above by the generator's `.throw` or
#      60 # `.send` methods bubble up to our caller, except for StopIteration
#      61 except StopIteration as e:
#      62     # The generator informed us that it is done: take whatever its
#      63     # returned value (if any) was and indicate that we're done too
#      64     # by returning it (see docs for python's return-statement).
#
# File c:\Users\Acer\anaconda3\envs\VC_P4\lib\site-packages\ultralytics\engine\predictor.py:254, in BasePredictor.stream_inference(self, source, model, *args, **kwargs)
#     252 # Inference
#     253 with profilers[1]:
# --> 254     preds = self.inference(im, *args, **kwargs)
#     255     if self.args.embed:
#     256         yield from [preds] if isinstance(preds, torch.Tensor) else preds  # yield embedding tensors
#
# File c:\Users\Acer\anaconda3\envs\VC_P4\lib\site-packages\ultralytics\engine\predictor.py:142, in BasePredictor.inference(self, im, *args, **kwargs)
#     136 """Runs inference on a given image using the specified model and arguments."""
#     137 visualize = (
#     138     increment_path(self.save_dir / Path(self.batch[0][0]).stem, mkdir=True)
#     139     if self.args.visualize and (not self.source_type.tensor)
#     140     else False
#     141 )
# --> 142 return self.model(im, augment=self.args.augment, visualize=visualize, embed=self.args.embed, *args, **kwargs)
#
# File c:\Users\Acer\anaconda3\envs\VC_P4\lib\site-packages\torch\nn\modules\module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File c:\Users\Acer\anaconda3\envs\VC_P4\lib\site-packages\torch\nn\modules\module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File c:\Users\Acer\anaconda3\envs\VC_P4\lib\site-packages\ultralytics\nn\autobackend.py:465, in AutoBackend.forward(self, im, augment, visualize, embed)
#     463 # PyTorch
#     464 if self.pt or self.nn_module:
# --> 465     y = self.model(im, augment=augment, visualize=visualize, embed=embed)
#     467 # TorchScript
#     468 elif self.jit:
#
# File c:\Users\Acer\anaconda3\envs\VC_P4\lib\site-packages\torch\nn\modules\module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File c:\Users\Acer\anaconda3\envs\VC_P4\lib\site-packages\torch\nn\modules\module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File c:\Users\Acer\anaconda3\envs\VC_P4\lib\site-packages\ultralytics\nn\tasks.py:112, in BaseModel.forward(self, x, *args, **kwargs)
#     110 if isinstance(x, dict):  # for cases of training and validating while training.
#     111     return self.loss(x, *args, **kwargs)
# --> 112 return self.predict(x, *args, **kwargs)
#
# File c:\Users\Acer\anaconda3\envs\VC_P4\lib\site-packages\ultralytics\nn\tasks.py:130, in BaseModel.predict(self, x, profile, visualize, augment, embed)
#     128 if augment:
#     129     return self._predict_augment(x)
# --> 130 return self._predict_once(x, profile, visualize, embed)
#
# File c:\Users\Acer\anaconda3\envs\VC_P4\lib\site-packages\ultralytics\nn\tasks.py:151, in BaseModel._predict_once(self, x, profile, visualize, embed)
#     149 if profile:
#     150     self._profile_one_layer(m, x, dt)
# --> 151 x = m(x)  # run
#     152 y.append(x if m.i in self.save else None)  # save output
#     153 if visualize:
#
# File c:\Users\Acer\anaconda3\envs\VC_P4\lib\site-packages\torch\nn\modules\module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File c:\Users\Acer\anaconda3\envs\VC_P4\lib\site-packages\torch\nn\modules\module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File c:\Users\Acer\anaconda3\envs\VC_P4\lib\site-packages\ultralytics\nn\modules\conv.py:54, in Conv.forward_fuse(self, x)
#      52 def forward_fuse(self, x):
#      53     """Perform transposed convolution of 2D data."""
# ---> 54     return self.act(self.conv(x))
#
# File c:\Users\Acer\anaconda3\envs\VC_P4\lib\site-packages\torch\nn\modules\module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File c:\Users\Acer\anaconda3\envs\VC_P4\lib\site-packages\torch\nn\modules\module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File c:\Users\Acer\anaconda3\envs\VC_P4\lib\site-packages\torch\nn\modules\activation.py:432, in SiLU.forward(self, input)
#     431 def forward(self, input: Tensor) -> Tensor:
# --> 432     return F.silu(input, inplace=self.inplace)
#
# File c:\Users\Acer\anaconda3\envs\VC_P4\lib\site-packages\torch\nn\functional.py:2379, in silu(input, inplace)
#    2377     return handle_torch_function(silu, (input,), input, inplace=inplace)
#    2378 if inplace:
# -> 2379     return torch._C._nn.silu_(input)
#    2380 return torch._C._nn.silu(input)
#
# KeyboardInterrupt:

# %%
import cv2  
import math 
import csv
import numpy as np
from ultralytics import YOLO
import pytesseract

# Configuración de Tesseract para OCR
pytesseract.pytesseract.tesseract_cmd = r'C:/Program Files/Tesseract-OCR/tesseract'

# Cargar modelos
model_deteccion = YOLO("yolo11n.pt")  # Modelo YOLO para detectar personas y vehículos
model_matriculas = YOLO("runs/detect/train3/weights/best.pt")  # Modelo para detectar matrículas

# Nombre del archivo de video
filename = "C0142.MP4"

# Abrir archivo CSV para guardar los resultados
csv_file = open('detecciones.csv', mode='w', newline='')
csv_writer = csv.writer(csv_file)
csv_writer.writerow(['fotograma', 'tipo_objeto', 'confianza', 'identificador_tracking', 'x1', 'y1', 'x2', 'y2', 'matrícula_en_su_caso', 'confianza_matricula', 'mx1', 'my1', 'mx2', 'my2', 'texto_matricula'])

# Abrir el video
cap = cv2.VideoCapture(filename)

# Configuración del video de salida
output_filename = "video_con_detecciones.mp4"
fps = cap.get(cv2.CAP_PROP_FPS)
width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
fourcc = cv2.VideoWriter_fourcc(*'mp4v')  # Codec para formato MP4
out = cv2.VideoWriter(output_filename, fourcc, fps, (width, height))

conteo_clases = {}  # Conteo total por clase
objetos_contados = {}  # Diccionario para rastrear IDs ya contados por clase
frame_count = 0
tracking_ids = {}  # Para gestionar los IDs de seguimiento
inactive_threshold = 5  # Número de fotogramas para mantener un ID inactivo
detected_ids = set()  # Conjunto para rastrear IDs ya detectados en este fotograma

while True:
    ret, frame = cap.read()
    if not ret:
        break

    # Detección de vehículos y personas
    results = model_deteccion.track(frame, stream=True, persist=True, verbose=False)

    for r in results:
        boxes = r.boxes

        for box in boxes:
            # Extraer coordenadas de la caja delimitadora
            x1, y1, x2, y2 = box.xyxy[0]
            x1, y1, x2, y2 = int(x1), int(y1), int(x2), int(y2)

            # Clase y confianza de la detección
            cls = int(box.cls[0])
            confianza = math.ceil((box.conf[0] * 100)) / 100
            tipo_objeto = model_deteccion.names[cls]  # Obtener la etiqueta de clase

            # ID de seguimiento del objeto
            tracking_id = str(int(box.id[0].tolist())) if box.id is not None else ''
            
            # Solo procesar si hay un tracking_id
            if tracking_id:
                # Agregar el ID al conjunto de IDs detectados
                detected_ids.add(tracking_id)

                # Contar el objeto solo si no ha sido contado ya
                if tracking_id not in objetos_contados:
                    objetos_contados[tracking_id] = tipo_objeto
                    # Contar el objeto por tipo
                    conteo_clases[tipo_objeto] = conteo_clases.get(tipo_objeto, 0) + 1

            # Si es un vehículo, intentamos detectar la matrícula
            matricula_text = ""
            conf_matricula = 0
            mx1, my1, mx2, my2 = 0, 0, 0, 0
            if tipo_objeto in ["car", "bus", "motorcycle"]:  # Asumiendo que solo estos son vehículos
                vehiculo_roi = frame[y1:y2, x1:x2]  # Recortar la imagen solo en el área del vehículo
                matricula_results = model_matriculas.track(vehiculo_roi, stream=True, verbose=False)
                
                for mat_result in matricula_results:
                    mat_boxes = mat_result.boxes
                    for mat_box in mat_boxes:
                        mx1, my1, mx2, my2 = mat_box.xyxy[0]
                        mx1, my1, mx2, my2 = int(mx1), int(my1), int(mx2), int(my2)
                        
                        # Convertir a imagen y usar OCR para texto
                        matricula_roi = vehiculo_roi[my1:my2, mx1:mx2]
                        if matricula_roi is not None:
                            matricula_text = pytesseract.image_to_string(matricula_roi, config='--psm 7')
                            conf_matricula = math.ceil((mat_box.conf[0] * 100)) / 100
                        else:
                            matricula_text = ""
                            conf_matricula = 0
                        cv2.rectangle(frame, (mx1 + x1, my1 + y1), (mx2 + x1, my2 + y1), (0, 255, 0), 2)

            # Guardar resultados en el CSV
            csv_writer.writerow([frame_count, tipo_objeto, confianza, tracking_id, x1, y1, x2, y2, matricula_text, conf_matricula, mx1, my1, mx2, my2, matricula_text])
            
            # Dibujar en la imagen, incluyendo el ID de seguimiento si está disponible
            cv2.putText(frame, f"{tipo_objeto} {tracking_id} {confianza}", (x1, y1 - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.9, (255, 0, 0), 2)
            cv2.rectangle(frame, (x1, y1), (x2, y2), (255, 0, 0), 2)
            if matricula_text:
                cv2.putText(frame, f"Matrícula: {matricula_text}", (x1, y2 + 20), cv2.FONT_HERSHEY_SIMPLEX, 0.9, (0, 255, 0), 2)

    # Eliminar IDs no detectados en este fotograma del conjunto de IDs detectados
    for tid in list(objetos_contados.keys()):
        if tid not in detected_ids:
            del objetos_contados[tid]  # Eliminar el ID del conteo si no fue detectado

    detected_ids.clear()  # Limpiar el conjunto de IDs detectados para el siguiente fotograma

    # Mostrar el video con las detecciones
    cv2.imshow('Detección y Seguimiento', frame)
    out.write(frame)

    frame_count += 1
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Resumen de conteo de clases
print("Conteo total de clases detectadas:")
for clase, conteo in conteo_clases.items():
    print(f"{clase}: {conteo}")

# Cerrar todo
cap.release()
out.release()
csv_file.close()
cv2.destroyAllWindows()
# Out:
# Conteo total de clases detectadas:
# bus: 1
# car: 44
# person: 14
# motorcycle: 1
# skateboard: 1
